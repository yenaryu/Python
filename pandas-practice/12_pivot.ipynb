# %% [markdown]
# #### 피봇 테이블

# %%
import pandas as pd
import random

random.seed(0)

num_rows = 10000
data = {
    "지점": [
        random.choice(["학여울역점", "강남역점", "건대역점", "홍대역점", "상섬역점"])
        for _ in range(num_rows)
    ],
    "제품": [
        random.choice(["노트북", "스마트폰", "냉장고", "세탁기", "건조기"])
        for _ in range(num_rows)
    ],
    "판매량": [random.randint(100, 500) for _ in range(num_rows)],
    "매출": [random.randint(1000, 5000) for _ in range(num_rows)],
}

df = pd.DataFrame(data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지점      10000 non-null  object
#  1   제품      10000 non-null  object
#  2   판매량     10000 non-null  int64
#  3   매출      10000 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 312.6+ KB

# %%
df.head()
# Out:
#       지점    제품  판매량    매출
# 0   홍대역점   노트북  290  4582
# 1   홍대역점  스마트폰  149  4528
# 2  학여울역점  스마트폰  475  1712
# 3   건대역점   세탁기  448  1748
# 4   상섬역점   냉장고  267  4035

# %%
df.tail()
# Out:
#          지점    제품  판매량    매출
# 9995   강남역점  스마트폰  468  3201
# 9996   상섬역점   냉장고  241  4811
# 9997   건대역점  스마트폰  212  3744
# 9998  학여울역점   노트북  273  1998
# 9999   건대역점   건조기  208  4071

# %%
#지점 - "행"
#제품 - "열"
#값(셀) - "판매량"
#Dataframe.pivot(index, columns, values)

df.pivot_table(index="지점", columns="제품", values="판매량")
# Out:
# 제품            건조기         냉장고         노트북         세탁기        스마트폰
# 지점
# 강남역점   305.785714  295.175487  296.698376  305.847328  292.360000
# 건대역점   293.139024  299.735802  304.928406  304.324742  299.821705
# 상섬역점   305.521739  300.927007  289.262467  306.812155  301.449315
# 학여울역점  305.392683  296.428198  306.158690  309.103448  307.943902
# 홍대역점   294.000000  303.141388  306.990453  287.258065  289.748235

# %%
df.pivot_table(index="지점", columns="제품", values="매출")
# Out:
# 제품             건조기          냉장고          노트북          세탁기         스마트폰
# 지점
# 강남역점   2911.731527  3021.515320  3070.276102  2959.173028  2984.797647
# 건대역점   3018.882927  2912.417284  3085.930716  2962.038660  3021.651163
# 상섬역점   2957.842105  3094.970803  3030.183727  2966.820442  2969.087671
# 학여울역점  2946.546341  3022.817232  2959.292191  2939.073892  3115.265854
# 홍대역점   3009.575758  2957.136247  3126.293556  3072.965054  3143.611765

# %%
#지점에 대한 제품의 판매량 평균
#aggfunc : 적용할 집계함수 이름름
df.pivot_table(index="지점",columns="제품",values="판매량",aggfunc="mean")
# Out:
# 제품            건조기         냉장고         노트북         세탁기        스마트폰
# 지점
# 강남역점   305.785714  295.175487  296.698376  305.847328  292.360000
# 건대역점   293.139024  299.735802  304.928406  304.324742  299.821705
# 상섬역점   305.521739  300.927007  289.262467  306.812155  301.449315
# 학여울역점  305.392683  296.428198  306.158690  309.103448  307.943902
# 홍대역점   294.000000  303.141388  306.990453  287.258065  289.748235

# %%
#각 지점에 대한 제품의 판매량 합계
df.pivot_table(index="지점", columns="제품",values="판매량",aggfunc="sum")
# Out:
# 제품        건조기     냉장고     노트북     세탁기    스마트폰
# 지점
# 강남역점   124149  105968  127877  120198  124253
# 건대역점   120187  121393  132034  118078  116031
# 상섬역점   133513  123681  110209  111066  110029
# 학여울역점  125211  113532  121545  125496  126257
# 홍대역점   116424  117922  128629  106860  123143

# %%
#열(columns)지정이 필수는 아니다
df.pivot_table(index="지점", values="판매량", aggfunc="sum")
# Out:
#           판매량
# 지점
# 강남역점   602445
# 건대역점   607723
# 상섬역점   588498
# 학여울역점  612041
# 홍대역점   592978

# %%
#여러개의 index와 여러개의 value 지정
#리스트[]에 저장해서 지정
df.pivot_table(index=["지점", "제품"], values=["판매량", "매출"], aggfunc="min")
# Out:
#               매출  판매량
# 지점    제품
# 강남역점  건조기   1007  101
#       냉장고   1006  104
#       노트북   1003  100
#       세탁기   1006  100
#       스마트폰  1013  100
# 건대역점  건조기   1011  102
#       냉장고   1007  100
#       노트북   1016  100
#       세탁기   1013  100
#       스마트폰  1005  101
# 상섬역점  건조기   1006  101
#       냉장고   1003  100
#       노트북   1002  100
#       세탁기   1004  101
#       스마트폰  1004  101
# 학여울역점 건조기   1017  101
#       냉장고   1001  100
#       노트북   1001  100
#       세탁기   1002  100
#       스마트폰  1017  100
# 홍대역점  건조기   1037  100
#       냉장고   1003  100
#       노트북   1010  100
#       세탁기   1007  100
#       스마트폰  1027  100

# %%
import pandas as pd

df = pd.read_csv("./vgsales.csv")

# %%
df.head(10)
# Out:
#                             title console             genre       publisher  \
# 0              Grand Theft Auto V     PS3            Action  Rockstar Games
# 1              Grand Theft Auto V     PS4            Action  Rockstar Games
# 2     Grand Theft Auto: Vice City     PS2            Action  Rockstar Games
# 3              Grand Theft Auto V    X360            Action  Rockstar Games
# 4       Call of Duty: Black Ops 3     PS4           Shooter      Activision
# 5  Call of Duty: Modern Warfare 3    X360           Shooter      Activision
# 6         Call of Duty: Black Ops    X360           Shooter      Activision
# 7           Red Dead Redemption 2     PS4  Action-Adventure  Rockstar Games
# 8      Call of Duty: Black Ops II    X360           Shooter      Activision
# 9      Call of Duty: Black Ops II     PS3           Shooter      Activision
#
#         developer  critic_score  total_sales  na_sales  jp_sales  pal_sales  \
# 0  Rockstar North           9.4        20.32      6.37      0.99       9.85
# 1  Rockstar North           9.7        19.39      6.06      0.60       9.71
# 2  Rockstar North           9.6        16.15      8.41      0.47       5.49
# 3  Rockstar North           NaN        15.86      9.06      0.06       5.33
# 4        Treyarch           8.1        15.09      6.18      0.41       6.05
# 5   Infinity Ward           8.7        14.82      9.07      0.13       4.29
# 6        Treyarch           8.8        14.74      9.76      0.11       3.73
# 7  Rockstar Games           9.8        13.94      5.26      0.21       6.21
# 8        Treyarch           8.4        13.86      8.27      0.07       4.32
# 9        Treyarch           8.0        13.80      4.99      0.65       5.88
#
#    other_sales release_date
# 0         3.12   2013-09-17
# 1         3.02   2014-11-18
# 2         1.78   2002-10-28
# 3         1.42   2013-09-17
# 4         2.44   2015-11-06
# 5         1.33   2011-11-08
# 6         1.14   2010-11-09
# 7         2.26   2018-10-26
# 8         1.20   2012-11-13
# 9         2.28   2012-11-13

# %%
#console 열을 기준으로 total_sales 의 합계를 계산한 피봇 테이블을 출력한다.
result = df.pivot_table(index="console",values="total_sales",aggfunc="sum")
result.loc["PS"]
# Out:
# total_sales    546.25
# Name: PS, dtype: float64

# %%
#console 열을 기준으로 total_sales 의 합계를 계산한 피봇 테이블을 출력한다.
df.pivot_table(index="genre",values="total_sales",aggfunc="mean").sort_values(by="total_sales")
# Out:
#                   total_sales
# genre
# Visual Novel         0.026514
# Board Game           0.110000
# Strategy             0.144280
# Adventure            0.171891
# Puzzle               0.176044
# Party                0.214138
# Education            0.242500
# Simulation           0.268198
# Misc                 0.278338
# Role-Playing         0.286251
# MMO                  0.310333
# Music                0.352041
# Platform             0.367140
# Racing               0.367400
# Fighting             0.391653
# Action               0.396580
# Sports               0.457262
# Action-Adventure     0.562576
# Shooter              0.670370
# Sandbox              1.890000

# %%
#genre 열과 console 열을 각각 행과 열로 지정하여 total_sales 의 평균을 계산한 피봇 테이블을 출력한다.
df.pivot_table(index="genre", columns="console", values="total_sales",aggfunc="mean")
# Out:
# console               2600   3DO       3DS        DC        DS        GB  \
# genre
# Action            0.462540   NaN  0.146637  0.060000  0.211165  0.620000
# Action-Adventure       NaN   NaN  0.242581       NaN  0.190000       NaN
# Adventure              NaN  0.06  0.115000  0.132000  0.197147  0.260000
# Board Game             NaN   NaN       NaN       NaN       NaN       NaN
# Education              NaN   NaN  0.090000       NaN       NaN       NaN
# Fighting          0.620000  0.09  0.160714  0.135455  0.171892       NaN
# MMO                    NaN   NaN  0.170000       NaN       NaN       NaN
# Misc              0.255000   NaN  0.116667       NaN  0.151187  0.565000
# Music                  NaN   NaN  0.177778       NaN       NaN       NaN
# Party                  NaN   NaN  0.345714       NaN       NaN       NaN
# Platform          1.096250   NaN  0.230000  1.270000  0.260400  0.185000
# Puzzle            0.713333  0.02  0.170909       NaN  0.148413  0.385714
# Racing            0.638000   NaN  0.169167  0.441667  0.191806       NaN
# Role-Playing           NaN   NaN  0.236623  0.170000  0.165105  0.442727
# Sandbox                NaN   NaN       NaN       NaN       NaN       NaN
# Shooter           0.918400   NaN  0.107143  0.110000  0.155435       NaN
# Simulation             NaN  0.02  0.221321  0.520000  0.264214  0.710000
# Sports            0.285833   NaN  0.228710  0.366000  0.184157  0.410000
# Strategy               NaN   NaN  0.103333       NaN  0.179125  0.410000
# Visual Novel           NaN   NaN  0.018000       NaN  0.010000       NaN
#
# console                GBA   GBC        GC       GEN  ...      SNES     VC  \
# genre                                                 ...
# Action            0.240058   NaN  0.230494  1.037500  ...  0.154000    NaN
# Action-Adventure       NaN   NaN       NaN       NaN  ...       NaN    NaN
# Adventure         0.362037  1.89  0.247097  0.095000  ...  0.375000    NaN
# Board Game             NaN   NaN       NaN       NaN  ...       NaN    NaN
# Education              NaN   NaN  0.120000       NaN  ...       NaN    NaN
# Fighting          0.161923   NaN  0.277500  1.110000  ...  0.540476  0.000
# MMO                    NaN   NaN       NaN       NaN  ...       NaN    NaN
# Misc              0.287692   NaN  0.193103  0.030000  ...  0.141875    NaN
# Music             0.300000   NaN       NaN       NaN  ...       NaN    NaN
# Party                  NaN   NaN       NaN       NaN  ...       NaN    NaN
# Platform          0.354600   NaN  0.251159  0.917500  ...  0.384706  0.005
# Puzzle            0.217600   NaN  0.356667       NaN  ...  0.490769    NaN
# Racing            0.165467   NaN  0.215000  0.260000  ...  0.268571    NaN
# Role-Playing      0.284032  0.56  0.213182  0.087500  ...  0.260833  0.000
# Sandbox                NaN   NaN       NaN       NaN  ...       NaN    NaN
# Shooter           0.078511   NaN  0.196122  0.130000  ...  0.178750    NaN
# Simulation        0.250000   NaN  0.456923       NaN  ...  0.358571    NaN
# Sports            0.159612   NaN  0.179182  1.066667  ...  0.364694  0.170
# Strategy          0.290000   NaN  0.165556  0.190000  ...  0.272857    NaN
# Visual Novel           NaN   NaN       NaN       NaN  ...       NaN    NaN
#
# console              WS    WW       Wii      WiiU      X360        XB    XBL  \
# genre
# Action              NaN   NaN  0.357022  0.211154  0.694850  0.298571  0.075
# Action-Adventure    NaN   NaN  0.362500  0.285200  0.910741  0.710000    NaN
# Adventure           NaN   NaN  0.289174  0.100000  0.419545  0.169333    NaN
# Board Game          NaN   NaN       NaN       NaN  0.020000       NaN    NaN
# Education           NaN   NaN       NaN       NaN  0.520000       NaN    NaN
# Fighting            NaN   NaN  0.231957  0.130000  0.576462  0.246042  0.010
# MMO                 NaN   NaN       NaN  0.156667       NaN       NaN    NaN
# Misc                NaN  0.25  0.421031  0.246000  0.418406  0.206889  0.000
# Music               NaN   NaN  0.790435  0.296923  0.470000       NaN    NaN
# Party               NaN   NaN  0.400000  0.221667  0.220000  0.090000    NaN
# Platform            NaN   NaN  0.350213  0.215625  0.520000  0.196327  0.005
# Puzzle              NaN   NaN  0.146000  0.097143  0.154545  0.066667    NaN
# Racing              NaN  0.00  0.232202  0.170000  0.587345  0.222742  0.030
# Role-Playing      0.305   NaN  0.216923  0.540000  0.868000  0.559048    NaN
# Sandbox             NaN   NaN       NaN       NaN       NaN       NaN    NaN
# Shooter             NaN   NaN  0.336061  0.189000  1.145297  0.352932  0.000
# Simulation          NaN   NaN  0.355056       NaN  0.274500  0.275926    NaN
# Sports              NaN   NaN  0.341296  0.397778  0.592815  0.308068    NaN
# Strategy          0.070   NaN  0.187727  0.010000  0.222857  0.136000    NaN
# Visual Novel        NaN   NaN       NaN       NaN  0.025000       NaN    NaN
#
# console               XOne
# genre
# Action            0.457647
# Action-Adventure  0.509000
# Adventure         0.103714
# Board Game             NaN
# Education              NaN
# Fighting          0.343125
# MMO               0.543333
# Misc              0.565000
# Music             0.350769
# Party             0.050000
# Platform          0.193810
# Puzzle            0.073333
# Racing            0.254310
# Role-Playing      0.428235
# Sandbox                NaN
# Shooter           1.389538
# Simulation        0.124286
# Sports            0.717647
# Strategy          0.063529
# Visual Novel      0.020000
#
# [20 rows x 39 columns]
