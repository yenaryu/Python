# %%
import pandas as pd #as : pd(pandas의 별칭(별명))

# %%
#데이터 프레임으로 만들 데이터 생성
data = {
    #Series(열)이 2개 (딕셔너리의 key가 2개)
    #열 내부의 데이터 타입은 동일하다
    "name" : ["민수", "지연", "현우", "수진", "영호", "민지", "지훈", "혜진"],
    "age" : [16, 18, 17, 15, 35, 10, 39, 59]
}

#Pandas의 데이터프레임 객체 생성
df=pd.DataFrame(data) #df = dataframe
print(df)
# Out:
#   name  age
# 0   민수   16
# 1   지연   18
# 2   현우   17
# 3   수진   15
# 4   영호   35
# 5   민지   10
# 6   지훈   39
# 7   혜진   59

# %%
#리스트 활용 데이터프레임 코드 생성
data = [
    {"name":"민수", "age":16},
    {"name":"지연", "age":18},
    {"name":"현우", "age":17},
    {"name":"수진", "age":15},
    {"name":"영호", "age":35},
    {"name":"민지", "age":10},
    {"name":"지훈", "age":39},
    {"name":"혜진", "age":59},
]
df = pd.DataFrame(data)
print()

# %%
data = {
    "Name" : ["Jay", "Anna", "Peter", "Linda"],
    "Age" : [28, 34, 29, 32],
    "Salary" : [50000, 62000, 58000, 75000]
}

df=pd.DataFrame(data)
df #print없이 변수명만 입력할 경우 더 예쁘게 출력됨됨
# Out:
#     Name  Age  Salary
# 0    Jay   28   50000
# 1   Anna   34   62000
# 2  Peter   29   58000
# 3  Linda   32   75000

# %%
#TMDB 영화 정보(Detail) 응답 데이터를 저장한 데이터프레임을 만드는 코드를 작성

import requests
from pprint import pprint

# 1. Detail API(https://developer.themoviedb.org/reference/movie-details)을 요청하여 영화 정보 저장
# Token 준비
api_token = "eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIxYzI5OTlkNGQyZmM3YmMyYmViMmQ5OGVkZjQ1Njk0MiIsIm5iZiI6MTczNDM5NTE4My43ODIsInN1YiI6IjY3NjBjNTJmNjExNjYxZTEwNDZiZTlmYiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.k5lziHC6UucR1Skiyg0KergiWYlGTFgwShQZQZpnOLY"

# request_url 준비
base_url = "https://api.themoviedb.org/3/"
movie_id = "912649"
endpoint = f"movie/{movie_id}"  # MOVIE - Details
request_url = base_url + endpoint

params = {
    "language": "ko-KR",
}

headers = {
    "Authorization": f"Bearer {api_token}",
}

# requests.get() 요청
response_data = requests.get(request_url, params=params, headers=headers).json()
print(type(response_data))
pprint(response_data)

#2. 영화 정보를 가지고, data변수 생성. 
# 필요 데이터 : id, overview, title, release_date
id = response_data["id"]
overview = response_data["overview"]
title = response_data["title"]
release_date = response_data["release_date"]

print(id, overview, title, release_date)

data = [
    {"id" : id,
     "overview" : overview,
     "title" : title,
     "release_date" : release_date
     }
]
pprint(data)

#3. data변수로 데이터프레임 생성
df=pd.DataFrame(data)
df
# Out:
# <class 'dict'>
# {'adult': False,
#  'backdrop_path': '/3V4kLQg0kSqPLctI5ziYWabAZYF.jpg',
#  'belongs_to_collection': {'backdrop_path': '/vq340s8DxA5Q209FT8PHA6CXYOx.jpg',
#                            'id': 558216,
#                            'name': '베놈 시리즈',
#                            'poster_path': '/4bXIKqdZIjR8wKgZaGDaLhLj4yF.jpg'},
#  'budget': 120000000,
#  'genres': [{'id': 28, 'name': '액션'},
#             {'id': 878, 'name': 'SF'},
#             {'id': 12, 'name': '모험'},
#             {'id': 53, 'name': '스릴러'}],
#  'homepage': '',
#  'id': 912649,
#  'imdb_id': 'tt16366836',
#  'origin_country': ['US'],
#  'original_language': 'en',
#  'original_title': 'Venom: The Last Dance',
#  'overview': '환상의 케미스트리의 에디 브록과 그의 심비오트 베놈은 그들을 노리는 정체불명 존재의 추격을 피해 같이 도망을 다니게 '
#              '된다. 한편 베놈의 창조자 널은 고향 행성에서부터 그들을 찾아내기 위해 지구를 침략하고 에디와 베놈은 그동안 '
#              '겪어보지 못한 최악의 위기를 맞이하게 되는데…',
#  'popularity': 6191.971,
#  'poster_path': '/rajTvnpDKRupZPpKJRxeJMKrIs6.jpg',
# ...

# %%
# 현재 상영 중(Now Playing)인 영화 정보 API 요청하여, 여러개의 응답 데이터를 저장한 데이터프레임을 만드는 코드를 작성
import requests
from pprint import pprint

# 영화 정보 저장
api_token = "eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIxYzI5OTlkNGQyZmM3YmMyYmViMmQ5OGVkZjQ1Njk0MiIsIm5iZiI6MTczNDM5NTE4My43ODIsInN1YiI6IjY3NjBjNTJmNjExNjYxZTEwNDZiZTlmYiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.k5lziHC6UucR1Skiyg0KergiWYlGTFgwShQZQZpnOLY"
base_url = "https://api.themoviedb.org/3/"
endpoint = "movie/now_playing"
request_url = base_url + endpoint

headers = {
    "Authorization": f"Bearer {api_token}",
}

# requests.get() 요청
response_data = requests.get(request_url, params=params, headers=headers).json()
movie_list = response_data['results']
print(type(response_data))
pprint(movie_list)

#개별 영화 정보를 저장한 리스트 > 데이터프레임의 기반 데이터가 될 리스트트
data = []
for movie in movie_list:
    print(movie)
    #개별 영화 정보에서 필요한 데이터만 추출하는 과정
    id = movie["id"]
    overview = movie["overview"]
    title = movie["title"]
    release_date = movie["release_date"]

    #개별 영화 정보를 쌓는 과정
    data.append(
        {
            "id" : id,
            "overview" : overview,
            "title" : title,
            "release_date" : release_date
        }
    )

#3. data변수로 데이터프레임 생성
df=pd.DataFrame(data)
df
# Out:
# <class 'dict'>
# [{'adult': False,
#   'backdrop_path': '/bHkn3yuOFdu5LJcq67Odofhx6cb.jpg',
#   'genre_ids': [28, 14, 35],
#   'id': 845781,
#   'original_language': 'en',
#   'original_title': 'Red One',
#   'overview': "크리스마스 D-1, 철통같은 보안을 뚫고 코드명 '레드 원' 산타클로스가 납치되고 크리스마스가 사라질 위기에 "
#               "처했다! '레드 원'을 찾기 위해 사령관 '칼럼 드리프트'는 산타클로스 따위는 없다고 믿는 현상금 사냥꾼 '잭 "
#               "오말리'와 협력하기로 한다. 시작부터 삐그덕 거리는 이들 앞에 크리스마스의 존재를 위협하는 위험천만한 적들이 "
#               '나타나는데…',
#   'popularity': 6624.443,
#   'poster_path': '/4zNUNhVpSqFggxqvdSXDRzy1QwE.jpg',
#   'release_date': '2024-10-31',
#   'title': '레드 원',
#   'video': False,
#   'vote_average': 6.958,
#   'vote_count': 825},
#  {'adult': False,
#   'backdrop_path': '/tElnmtQ6yz1PjN1kePNl8yMSb59.jpg',
#   'genre_ids': [16, 12, 10751, 35],
#   'id': 1241982,
#   'original_language': 'en',
#   'original_title': 'Moana 2',
#   'overview': '바다를 누볐던 선조들에게서 예기치 못한 부름을 받은 모아나가 마우이와 다시 만나 새로운 선원들과 함께 오랫동안 '
# ...

# %%
df = pd.read_csv("./winequality-red.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
data = [
    {"name":"민수", "age":16},
    {"name":"지연", "age":18},
    {"name":"현우", "age":17},
    {"name":"수진", "age":15},
    {"name":"영호", "age":35},
    {"name":"민지", "age":10},
    {"name":"지훈", "age":39},
    {"name":"혜진", "age":59},
]
df = pd.DataFrame(data)
#저장하고 싶은 데이터프레임.to_파일형식
df.to_csv("./example.csv")

# %%
## 위치기반 관광정보 조회 API 데이터터를 데이터프레임으로 만들고, csv파일로 저장하는 코드를 작성한다

# requests 라이브러리 불러오기 + pprint 모듈 import
import requests
import pandas as pd
from pprint import pprint

serviceKey = "cUXcvgk5JU5s8EWoLWYB28L5mjyVbhLTD8FhyY7JxmBYxqNHgJMh3tDNnzOaMG5Umh2QVsEFm1T4jmTGz9rhPg=="
base_url = "http://apis.data.go.kr/B551011/KorService1/"
end_point = "locationBasedList1"
request_url = base_url + end_point

# 요청 변수 설정
numOfRows = 10  # 한페이지 결과 수
pageNo = 1  # 페이지번호
MobileOS = "AND"  # 호출OS
MobileApp = "kakaotalk"  # 호출 어플이름
mapX = 126.981611  # GPS X좌표 (서울경도)
mapY = 37.568477  # GPS Y좌표 (서울위도)
radius = 1000  # 거리반경
_type = "JSON"  # 응답 데이터의 형식

# 요청 변수 저장
params = {
    "serviceKey": serviceKey,
    "numOfRows": numOfRows,
    "pageNo": pageNo,
    "MobileOS": MobileOS,
    "MobileApp": MobileApp,
    "mapX": mapX,
    "mapY": mapY,
    "radius": radius,
    "_type": _type,
}

# API 요청
response = requests.get(request_url, params=params).json()
# pprint(response)
items = response["response"]["body"]["items"]["item"]

# 정보를 가지고, data변수 생성. 
# 필요 데이터 : addr1, mapx, mapy, title
data = [
    {
      "title": item["title"],
        "addr1": item["addr1"],
        "mapx": item["mapx"],
        "mapy": item["mapy"]
    }
     for item in items
]
# pprint(data)

df = pd.DataFrame(data)
pprint(df)

#tour_data.csv 저장장
df.to_csv("./tour_data.csv")
# Out:
#        title                         addr1            mapx           mapy
# 0   하이커 그라운드  서울특별시 중구 청계천로 40 한국관광공사 서울센터  126.9816428989  37.5685818430
# 1  위라이드 서울전차  서울특별시 중구 청계천로 40 한국관광공사 서울센터  126.9816373430  37.5686123950
# 2        가쯔야               서울특별시 중구 다동길 46  126.9817290217  37.5678958128
# 3        인천집               서울특별시 중구 다동길 36  126.9812818412  37.5678596976
# 4    다동 황소막창             서울특별시 중구 을지로3길 49  126.9807763209  37.5682235355
# 5        광통교                 서울특별시 종로구 서린동  126.9811151529  37.5691539885
# 6        호면정       서울특별시 종로구 청계천로 35 (서린동)  126.9813928988  37.5693928548
# 7        장안문             서울특별시 중구 을지로3길 29  126.9813651797  37.5674097516
# 8       손가명가               서울특별시 중구 다동길 13  126.9802541484  37.5681763099
# 9        용금옥             서울특별시 중구 다동길 24-2  126.9805263585  37.5677235893
